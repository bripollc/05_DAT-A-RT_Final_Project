# %%
import pandas as pd

# %%
art = pd.read_csv("WikiArt-annotations.csv")

# %%
art.head(15)
# Out:
#     Worker ID          ImageOnly #1: ID
# 0    worker_1  57728030edc2cb3880f07e00  \
# 1    worker_2  57728030edc2cb3880f07e00
# 2    worker_3  57728030edc2cb3880f07e00
# 3    worker_4  57728030edc2cb3880f07e00
# 4    worker_5  57728030edc2cb3880f07e00
# 5    worker_6  57728030edc2cb3880f07e00
# 6    worker_7  57728030edc2cb3880f07e00
# 7    worker_8  57728030edc2cb3880f07e00
# 8    worker_9  57728030edc2cb3880f07e00
# 9   worker_10  57728030edc2cb3880f07e00
# 10  worker_11  57726f0fedc2cb3880b94ae6
# 11  worker_12  57726f0fedc2cb3880b94ae6
# 12  worker_13  57726f0fedc2cb3880b94ae6
# 13  worker_14  57726f0fedc2cb3880b94ae6
# 14  worker_15  57726f0fedc2cb3880b94ae6
#
#                                ImageOnly #1: Emotions
# 0                                            surprise  \
# 1                                        anticipation
# 2                                             disgust
# 3                                        anticipation
# ...

# %%
art.columns
# Out:
# Index(['Worker ID', 'ImageOnly #1: ID', 'ImageOnly #1: Emotions',
#        'ImageOnly #1: Other Emotions', 'ImageOnly #2: ID',
#        'ImageOnly #2: Emotions', 'ImageOnly #2: Other Emotions',
#        'ImageOnly #3: ID', 'ImageOnly #3: Emotions',
#        'ImageOnly #3: Other Emotions', 'ImageOnly #4: ID',
#        'ImageOnly #4: Emotions', 'ImageOnly #4: Other Emotions',
#        'ImageOnly #5: ID', 'ImageOnly #5: Emotions',
#        'ImageOnly #5: Other Emotions', 'TitleOnly #1: ID',
#        'TitleOnly #1: Emotions', 'TitleOnly #1: Other Emotions',
#        'TitleOnly #2: ID', 'TitleOnly #2: Emotions',
#        'TitleOnly #2: Other Emotions', 'TitleOnly #3: ID',
#        'TitleOnly #3: Emotions', 'TitleOnly #3: Other Emotions',
#        'TitleOnly #4: ID', 'TitleOnly #4: Emotions',
#        'TitleOnly #4: Other Emotions', 'TitleOnly #5: ID',
#        'TitleOnly #5: Emotions', 'TitleOnly #5: Other Emotions',
#        'Art (image+title) #1: ID', 'Art (image+title) #1: Emotions',
# ...

# %%
new_column_name = 'Art_rat_5'
art = art.rename(columns={'Art (image+title) #5: Art rating': new_column_name})
art
# Out:
#         Worker ID          ImageOnly #1: ID
# 0        worker_1  57728030edc2cb3880f07e00  \
# 1        worker_2  57728030edc2cb3880f07e00
# 2        worker_3  57728030edc2cb3880f07e00
# 3        worker_4  57728030edc2cb3880f07e00
# 4        worker_5  57728030edc2cb3880f07e00
# ...           ...                       ...
# 12680   worker_37  577283c4edc2cb3880fbce85
# 12681  worker_101  577283c4edc2cb3880fbce85
# 12682   worker_15  577283c4edc2cb3880fbce85
# 12683   worker_79  577283c4edc2cb3880fbce85
# 12684    worker_3  577283c4edc2cb3880fbce85
#
#                       ImageOnly #1: Emotions ImageOnly #1: Other Emotions
# 0                                   surprise                          NaN  \
# 1                               anticipation                          NaN
# 2                                    disgust                          NaN
# 3                               anticipation                          NaN
# ...

# %%
art.Art_rat_5.value_counts()
# Out:
# Art_rat_5
#  2    3010
#  1    2752
#  0    2379
#  3    2195
# -1    1040
# -2     796
# -3     513
# Name: count, dtype: int64

# %%
art.loc[0][5]
# Out:
# '57726f0dedc2cb3880b94625'

# %%
art.isnull().sum()
# Out:
# Worker ID                                   0
# ImageOnly #1: ID                            0
# ImageOnly #1: Emotions                      0
# ImageOnly #1: Other Emotions            12559
# ImageOnly #2: ID                            0
#                                         ...
# Art (image+title) #5: Emotions              0
# Art (image+title) #5: Other Emotions    12531
# Art (image+title) #5: Is painting           0
# Art (image+title) #5: Face/body             0
# Art (image+title) #5: Art rating            0
# Length: 61, dtype: int64

# %%
ls
# Out:
# README.txt*               WikiArt-Emotions-Ag4.tsv  WikiArt-annotations.csv*
# Untitled.ipynb            WikiArt-Emotions-Ag5.tsv  WikiArt-info.tsv
# WikiArt-Emotions-Ag3.tsv  WikiArt-Emotions-All.tsv

# %%
import csv

# Specify the path to your TSV file
file_path = 'WikiArt-Emotions-Ag3.tsv'

# Open the file in read mode
with open(file_path, 'r') as tsv_file:
    # Create a CSV reader object
    reader = csv.reader(tsv_file, delimiter='\t')

    # Iterate over each row in the TSV file
    for row in reader:
        # Access individual columns using index
        column1 = row[0]
        column2 = row[1]
        # Process the data as needed
        print(column1, column2)
# Out:
# ID Style
# 58c6237dedc2c9c7dc0de1ae Modern Art
# 577280dfedc2cb3880f28e76 Modern Art
# 57727f2dedc2cb3880ed5fa9 Modern Art
# 58d1240cedc2c94f900fc610 Modern Art
# 57727de7edc2cb3880e91f26 Post Renaissance Art
# 57728297edc2cb3880f81f5b Modern Art
# 5772797dedc2cb3880db5504 Post Renaissance Art
# 57726e48edc2cb3880b69b14 Post Renaissance Art
# 57728255edc2cb3880f7644a Contemporary Art
# 5772843bedc2cb3880fd334d Contemporary Art
# 577285b4edc2cb388001c741 Modern Art
# 5772898cedc2cb38800df3fd Post Renaissance Art
# 5772849eedc2cb3880fe72ab Modern Art
# 577282b3edc2cb3880f89e19 Modern Art
# 577284a7edc2cb3880fe813a Modern Art
# 57727ca4edc2cb3880e54008 Renaissance Art
# 57726ff3edc2cb3880bc56a7 Post Renaissance Art
# 577288deedc2cb38800bdf0f Modern Art
# 57726e25edc2cb3880b60a8b Modern Art
# 577288ddedc2cb38800bde1d Contemporary Art
# 577287d9edc2cb38800895a7 Modern Art
# 57727dd9edc2cb3880e90d51 Post Renaissance Art
# 57726f83edc2cb3880bb117d Post Renaissance Art
# ...

# %%
../data/WikiArt-Emotions/WikiArt-annotations.csv
# Out:
#   Input In [1]
#     ../data/WikiArt-Emotions/WikiArt-annotations.csv
#     ^
# SyntaxError: invalid syntax
